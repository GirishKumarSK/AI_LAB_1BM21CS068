# %% [markdown]
# <a href="https://colab.research.google.com/github/GirishKumarSK/AI_LAB_1BM21CS068/blob/main/Praposition%20Logic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def clean_rooms(rooms):
    total_rooms = len(rooms)
    cur_pos = 0

    clean_room(rooms, cur_pos)

    cur_pos = (cur_pos + 1) % total_rooms
    clean_room(rooms,cur_pos)

    cur_pos = (cur_pos + 1) % total_rooms
    clean_room(rooms,cur_pos)
    print("Vacuum Cleaner is turning OFF")

def clean_room(rooms, pos):
    print(f"Vacuum Cleaner at Room {pos+1}")
    print(f"Is Room Cleaned ? {rooms[pos]==0}")

    if rooms[pos] == 1:
        print(f"Room {pos+1} is dirty. Cleaning....")
        rooms[pos] = 0
        print(f"Room {pos+1} is cleaned.")
    else:
        print(f"Roomn {pos+1} is already cleaned.")

rooms = [0,1]
clean_rooms(rooms)

# %%
def clean_four_rooms(rooms):
    total_rooms = len(rooms)
    cur_pos = 0

    clean_room(rooms, cur_pos)

    for i in range(0,total_rooms):
      cur_pos = (cur_pos + 1) % total_rooms
      clean_room(rooms, cur_pos)

    print("Vacuum Cleaner is turning OFF")

def clean_room(rooms, pos):
    print(f"Vacuum Cleaner at Room {pos+1}")
    print(f"Is Room Cleaned ? {rooms[pos]==0}")

    if rooms[pos] == 1:
        print(f"Room {pos+1} is dirty. Cleaning....")
        rooms[pos] = 0
        print(f"Room {pos+1} is cleaned.")
    else:
        print(f"Roomn {pos+1} is already cleaned.")

rooms = [0,1,0,1]
clean_four_rooms(rooms)
# Out:
# Vacuum Cleaner at Room 1
# Is Room Cleaned ? True
# Roomn 1 is already cleaned.
# Vacuum Cleaner at Room 2
# Is Room Cleaned ? False
# Room 2 is dirty. Cleaning....
# Room 2 is cleaned.
# Vacuum Cleaner at Room 3
# Is Room Cleaned ? True
# Roomn 3 is already cleaned.
# Vacuum Cleaner at Room 4
# Is Room Cleaned ? False
# Room 4 is dirty. Cleaning....
# Room 4 is cleaned.
# Vacuum Cleaner at Room 1
# Is Room Cleaned ? True
# Roomn 1 is already cleaned.
# Vacuum Cleaner is turning OFF

# %%
variable = {"p": 0, "q": 1, "r": 2}
priority = {"~": 3, "v": 1, "^": 2}


def _eval(i, val1, val2):
    if i == "^":
        return val2 and val1
    return val2 or val1


def isOperand(c):
    return c.isalpha() and c != "v"


def isLeftParanthesis(c):
    return c == "("


def isRightParanthesis(c):
    return c == ")"


def isEmpty(stack):
    return len(stack) == 0


def peek(stack):
    return stack[-1]


def hasLessOrEqualPriority(c1, c2):
    try:
        return priority[c1] <= priority[c2]
    except KeyError:
        return False


def toPostfix(infix):
    stack = []
    postfix = ""
    for c in infix:
        if isOperand(c):
            postfix += c
        else:
            if isLeftParanthesis(c):
                stack.append(c)
            elif isRightParanthesis(c):
                operator = stack.pop()
                while not isLeftParanthesis(operator):
                    postfix += operator
                    operator = stack.pop()
            else:
                while (not isEmpty(stack)) and hasLessOrEqualPriority(c, peek(stack)):
                    postfix += stack.pop()
                stack.append(c)
    while not isEmpty(stack):
        postfix += stack.pop()

    return postfix


def evaluatePostfix(exp, comb):
    stack = []
    for i in exp:
        if isOperand(i):
            stack.append(comb[variable[i]])
        elif i == "~":
            val1 = stack.pop()
            stack.append(not val1)
        else:
            val1 = stack.pop()
            val2 = stack.pop()
            stack.append(_eval(i, val2, val1))
    return stack.pop()


def CheckEntailment():
    kb = input("Enter the knowledge base: ")
    query = input("Enter the query: ")
    combinations = [
        [True, True, True],
        [True, True, False],
        [True, False, True],
        [True, False, False],
        [False, True, True],
        [False, True, False],
        [False, False, True],
        [False, False, False],
    ]
    postfix_kb = toPostfix(kb)
    postfix_q = toPostfix(query)
    for combination in combinations:
        eval_kb = evaluatePostfix(postfix_kb, combination)
        eval_q = evaluatePostfix(postfix_q, combination)
        print(combination, ":kb=", eval_kb, ":q=", eval_q)
        if eval_kb == True:
            if eval_q == False:
                print("Doesn't entail!! \U0001F92A")
                return False
    print("Entails")


if __name__ == "__main__":
    CheckEntailment()

# %%
variable = {"p": 0, "q": 1, "r": 2}
priority = {"~": 3, "v": 1, "^": 2}


def _eval(i, val1, val2):
    if i == "^":
        return val2 and val1
    return val2 or val1


def isOperand(c):
    return c.isalpha() and c != "v"


def isLeftParanthesis(c):
    return c == "("


def isRightParanthesis(c):
    return c == ")"


def isEmpty(stack):
    return len(stack) == 0


def peek(stack):
    return stack[-1]


def hasLessOrEqualPriority(c1, c2):
    try:
        return priority[c1] <= priority[c2]
    except KeyError:
        return False


def toPostfix(infix):
    stack = []
    postfix = ""
    for c in infix:
        if isOperand(c):
            postfix += c
        else:
            if isLeftParanthesis(c):
                stack.append(c)
            elif isRightParanthesis(c):
                operator = stack.pop()
                while not isLeftParanthesis(operator):
                    postfix += operator
                    operator = stack.pop()
            else:
                while (not isEmpty(stack)) and hasLessOrEqualPriority(c, peek(stack)):
                    postfix += stack.pop()
                stack.append(c)
    while not isEmpty(stack):
        postfix += stack.pop()

    return postfix


def evaluatePostfix(exp, comb):
    stack = []
    for i in exp:
        if isOperand(i):
            stack.append(comb[variable[i]])
        elif i == "~":
            val1 = stack.pop()
            stack.append(not val1)
        else:
            val1 = stack.pop()
            val2 = stack.pop()
            stack.append(_eval(i, val2, val1))
    return stack.pop()


def CheckEntailment():
    kb = input("Enter the knowledge base: ")
    query = input("Enter the query: ")
    combinations = [
        [True, True, True],
        [True, True, False],
        [True, False, True],
        [True, False, False],
        [False, True, True],
        [False, True, False],
        [False, False, True],
        [False, False, False],
    ]
    postfix_kb = toPostfix(kb)
    postfix_q = toPostfix(query)
    for combination in combinations:
        eval_kb = evaluatePostfix(postfix_kb, combination)
        eval_q = evaluatePostfix(postfix_q, combination)
        print(combination, ":kb=", eval_kb, ":q=", eval_q)
        if eval_kb == True:
            if eval_q == False:
                print("Doesn't entail!! \U0001F92A")
                return False
    print("Entails")


if __name__ == "__main__":
    CheckEntailment()
# Out:
# Enter the knowledge base: (p^q)^(~r)
# Enter the query: p^(q^r)
# [True, True, True] :kb= False :q= True
# [True, True, False] :kb= True :q= False
# Doesn't entail!! 🤪
